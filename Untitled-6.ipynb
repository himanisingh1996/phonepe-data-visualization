# %%
import pandas as pd

ColumnNames=['Hours','Calories', 'Weight']
DataValues=[[  1.0,   2500,   95],
             [  2.0,   2000,   85],
             [  2.5,   1900,   83],
             [  3.0,   1850,   81],
             [  3.5,   1600,   80],
             [  4.0,   1500,   78],
             [  5.0,   1500,   77],
             [  5.5,   1600,   80],
             [  6.0,   1700,   75],
             [  6.5,   1500,   70],
             [  1.3,   2200,   90],
             [  2.2,   1800,   87],
             [  3.2,   1750,   81],
             [  3.7,   1600,   80],
             [  4.2,   1550,   75],
             [  5.1,   1500,   79],
             [  5.8,   1650,   82],
             [  6.3,   1700,   72],
             [  6.5,   1400,   69]          
           
           ]

# Create the Data Frame
GymData=pd.DataFrame(data=DataValues,columns=ColumnNames)

display(GymData.head())

# ########################################################
# %matplotlib inline

# Positive correlation scatter plot
GymData.plot.scatter(x='Calories', y='Weight', marker='o', figsize=(7,5))

# Negative correlation scatter plot
GymData.plot.scatter(x='Hours', y='Weight', marker='o', figsize=(7,5))
# Out:
#    Hours  Calories  Weight
# 0    1.0      2500      95
# 1    2.0      2000      85
# 2    2.5      1900      83
# 3    3.0      1850      81
# 4    3.5      1600      80
# <Axes: xlabel='Hours', ylabel='Weight'>
